# %% [markdown]
# What is React?
#
#     -> React is JavaScript library used to build User Intereface, especially for web applications.
#     -> It was created by Meta platform.
#     -> It has reusable components like Navigation bar, Side bar, Footer.
#
# Why React?
#
#     -> Reusability
#     -> Faster UI updates
#     -> Component based Architecture

# %% [markdown]
# Single Page Architecture(SPA):
